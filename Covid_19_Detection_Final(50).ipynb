# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 23.9 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.layers import *
from keras.models import * 
from keras.preprocessing import image

# %%
import visualkeras
# CNN Based Model in Keras

model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

opt=tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
from PIL import ImageFont

font = ImageFont.load_default()
visualkeras.layered_view(model, legend=True, font=font)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  dropout (Dropout)           (None, 110, 110, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 54, 54, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 26, 26, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 5, 5, 128)         0
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 630,273
# Trainable params: 630,273
# Non-trainable params: 0
# _________________________________________________________________
# <PIL.Image.Image image mode=RGBA size=1062x1220 at 0x7F76F0185850>

# %%
# Train from scratch
train_datagen = image.ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
)

test_dataset = image.ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    'drive/MyDrive/Code_Test/Train',
    target_size = (224,224),
    batch_size = 64,
    class_mode = 'binary')
# Out:
# Found 920 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0, 'Normal': 1}

# %%
validation_generator = test_dataset.flow_from_directory(
    'drive/MyDrive/Code_Test/Val',
    target_size = (224,224),
    batch_size = 64,
    class_mode = 'binary')
# Out:
# Found 232 images belonging to 2 classes.

# %%
results = model.fit_generator(
    train_generator,
    steps_per_epoch=int(920/64),
    epochs = 50,
    validation_data = validation_generator
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 14/14 [==============================] - 166s 11s/step - loss: 0.6955 - accuracy: 0.5280 - val_loss: 0.6923 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.6551 - accuracy: 0.6016 - val_loss: 0.5826 - val_accuracy: 0.8362 - lr: 0.0010
# Epoch 3/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.5000 - accuracy: 0.7699 - val_loss: 0.4281 - val_accuracy: 0.9095 - lr: 0.0010
# Epoch 4/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.3785 - accuracy: 0.8594 - val_loss: 0.5914 - val_accuracy: 0.7716 - lr: 0.0010
# Epoch 5/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.3341 - accuracy: 0.8797 - val_loss: 0.1992 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 6/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.2479 - accuracy: 0.9112 - val_loss: 0.4386 - val_accuracy: 0.8103 - lr: 0.0010
# Epoch 7/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.2360 - accuracy: 0.9264 - val_loss: 0.1982 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 8/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.2509 - accuracy: 0.9100 - val_loss: 0.2702 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 9/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1946 - accuracy: 0.9369 - val_loss: 0.2914 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 10/50
# 14/14 [==============================] - 49s 3s/step - loss: 0.1787 - accuracy: 0.9381 - val_loss: 0.1135 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 11/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.2044 - accuracy: 0.9276 - val_loss: 0.1859 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 12/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1599 - accuracy: 0.9428 - val_loss: 0.1166 - val_accuracy: 0.9612 - lr: 0.0010
# Epoch 13/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.2126 - accuracy: 0.9275 - val_loss: 0.1822 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 14/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1826 - accuracy: 0.9346 - val_loss: 0.1988 - val_accuracy: 0.9224 - lr: 0.0010
# Epoch 15/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1301 - accuracy: 0.9521 - val_loss: 0.1077 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 16/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1672 - accuracy: 0.9393 - val_loss: 0.1419 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 17/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1840 - accuracy: 0.9357 - val_loss: 0.1661 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 18/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1102 - accuracy: 0.9650 - val_loss: 0.0999 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 19/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1289 - accuracy: 0.9603 - val_loss: 0.1170 - val_accuracy: 0.9612 - lr: 0.0010
# Epoch 20/50
# 14/14 [==============================] - 49s 3s/step - loss: 0.1062 - accuracy: 0.9673 - val_loss: 0.0813 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 21/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.0937 - accuracy: 0.9638 - val_loss: 0.0785 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 22/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1227 - accuracy: 0.9591 - val_loss: 0.0798 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 23/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0828 - accuracy: 0.9685 - val_loss: 0.0909 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 24/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1180 - accuracy: 0.9591 - val_loss: 0.1113 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 25/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1051 - accuracy: 0.9650 - val_loss: 0.0675 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 26/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0852 - accuracy: 0.9696 - val_loss: 0.0555 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 27/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0797 - accuracy: 0.9731 - val_loss: 0.0586 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 28/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.0995 - accuracy: 0.9661 - val_loss: 0.0491 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 29/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0750 - accuracy: 0.9743 - val_loss: 0.0494 - val_accuracy: 0.9784 - lr: 0.0010
# Epoch 30/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0747 - accuracy: 0.9696 - val_loss: 0.0751 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 31/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0794 - accuracy: 0.9708 - val_loss: 0.0692 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 32/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1192 - accuracy: 0.9614 - val_loss: 0.0511 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 33/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0764 - accuracy: 0.9665 - val_loss: 0.0415 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 34/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0789 - accuracy: 0.9755 - val_loss: 0.0846 - val_accuracy: 0.9569 - lr: 0.0010
# Epoch 35/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.1167 - accuracy: 0.9603 - val_loss: 0.0586 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 36/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0918 - accuracy: 0.9696 - val_loss: 0.0639 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 37/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0819 - accuracy: 0.9708 - val_loss: 0.0581 - val_accuracy: 0.9784 - lr: 0.0010
# Epoch 38/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0810 - accuracy: 0.9743 - val_loss: 0.0895 - val_accuracy: 0.9612 - lr: 0.0010
# Epoch 39/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0971 - accuracy: 0.9650 - val_loss: 0.0865 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 40/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0534 - accuracy: 0.9801 - val_loss: 0.0538 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 41/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0796 - accuracy: 0.9696 - val_loss: 0.0678 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 42/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0790 - accuracy: 0.9720 - val_loss: 0.0525 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 43/50
# 14/14 [==============================] - 52s 4s/step - loss: 0.0568 - accuracy: 0.9813 - val_loss: 0.0440 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 44/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0580 - accuracy: 0.9743 - val_loss: 0.0432 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 45/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.0549 - accuracy: 0.9825 - val_loss: 0.0385 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 46/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.0492 - accuracy: 0.9825 - val_loss: 0.0390 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 47/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0473 - accuracy: 0.9860 - val_loss: 0.0384 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 48/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0414 - accuracy: 0.9871 - val_loss: 0.0355 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 49/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.0565 - accuracy: 0.9836 - val_loss: 0.0360 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 50/50
# 14/14 [==============================] - 49s 3s/step - loss: 0.0531 - accuracy: 0.9860 - val_loss: 0.0342 - val_accuracy: 0.9871 - lr: 1.0000e-04

# %%
import matplotlib.pyplot as plt
def plot_acc_loss(results, epochs):
 acc = results.history['accuracy']
 loss = results.history['loss']
 val_acc = results.history['val_accuracy']
 val_loss = results.history['val_loss']
 plt.figure(figsize=(15, 5))
 plt.subplot(121)
 plt.plot(range(1,epochs), acc[1:], label='Train_acc',scaley=False)
 plt.plot(range(1,epochs), val_acc[1:], label='Test_acc',scaley=False)
 plt.title('Accuracy over' + str(epochs) + 'Epochs', size=15)
 plt.legend()
 plt.subplot(122)
 plt.plot(range(1,epochs), loss[1:], label='Train_loss')
 plt.plot(range(1,epochs), val_loss[1:], label='Test_loss')
 plt.title('Loss over' + str(epochs) +  'Epochs', size=15)
 plt.legend()
 plt.show()
 
plot_acc_loss(results, 50)

# %%
import numpy as np
from keras.preprocessing import image

test_image = image.load_img('drive/MyDrive/Code_Test/single_prediction/covid.jpeg', target_size = (224, 224))
test_image = image.img_to_array(test_image)/255
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(train_generator.class_indices)
# Out:
# {'Covid': 0, 'Normal': 1}

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('drive/MyDrive/Code_Test/single_prediction/covid.jpeg')
imgplot = plt.imshow(img)
plt=plt.title('CT Scan of COVID-19 Positive Patient')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['subtract', 'dot', 'multiply', 'concatenate', 'save', 'logging', 'add', 'maximum', 'average', 'minimum']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
if result[0][0] == 1:
    prediction = 'normal'
else:
    prediction = 'covid'
    
print("AI's prediction is: "+ prediction)
# Out:
# AI's prediction is: covid

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

test_image = image.load_img('drive/MyDrive/Code_Test/single_prediction/normal.jpeg', target_size = (224, 224))
test_image = image.img_to_array(test_image)/255
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(train_generator.class_indices)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# {'Covid': 0, 'Normal': 1}

# %%
img=mpimg.imread('drive/MyDrive/Code_Test/single_prediction/normal.jpeg')
imgplot = plt.imshow(img)
plt=plt.title('CT Scan of COVID-19 Negative Patient')

# %%
if result[0][0] == 1:
    prediction = 'normal'
else:
    prediction = 'covid'
    
print("AI's prediction is: "+ prediction)
# Out:
# AI's prediction is: normal
