# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 14.0 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.layers import *
from keras.models import * 
from keras.preprocessing import image

# %%
import visualkeras
# CNN Based Model in Keras

model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

opt=tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
from PIL import ImageFont

font = ImageFont.load_default()
visualkeras.layered_view(model, legend=True, font=font)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  dropout (Dropout)           (None, 110, 110, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 54, 54, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 26, 26, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 5, 5, 128)         0
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 630,273
# Trainable params: 630,273
# Non-trainable params: 0
# _________________________________________________________________
# <PIL.Image.Image image mode=RGBA size=1062x1220 at 0x7F4A5864B1D0>

# %%
# Train from scratch
train_datagen = image.ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
)

test_dataset = image.ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    'drive/MyDrive/Code_Test/Train',
    target_size = (224,224),
    batch_size = 64,
    class_mode = 'binary')
# Out:
# Found 920 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0, 'Normal': 1}

# %%
validation_generator = test_dataset.flow_from_directory(
    'drive/MyDrive/Code_Test/Val',
    target_size = (224,224),
    batch_size = 64,
    class_mode = 'binary')
# Out:
# Found 232 images belonging to 2 classes.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint('classification_deep_conv_model.h5', save_best_only=True),
    keras.callbacks.ReduceLROnPlateau()]

# %%
results = model.fit_generator(
    train_generator,
    steps_per_epoch=int(920/64),
    epochs = 50,
    validation_data = validation_generator,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 14/14 [==============================] - 60s 4s/step - loss: 0.7085 - accuracy: 0.4988 - val_loss: 0.6925 - val_accuracy: 0.4957 - lr: 0.0010
# Epoch 2/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.6422 - accuracy: 0.6425 - val_loss: 0.6098 - val_accuracy: 0.7414 - lr: 0.0010
# Epoch 3/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.4626 - accuracy: 0.7932 - val_loss: 0.3697 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 4/50
# 14/14 [==============================] - 49s 3s/step - loss: 0.3868 - accuracy: 0.8493 - val_loss: 0.2833 - val_accuracy: 0.8922 - lr: 0.0010
# Epoch 5/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.3473 - accuracy: 0.8727 - val_loss: 0.2957 - val_accuracy: 0.9440 - lr: 0.0010
# Epoch 6/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.2351 - accuracy: 0.9206 - val_loss: 0.1855 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 7/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1928 - accuracy: 0.9322 - val_loss: 0.1417 - val_accuracy: 0.9612 - lr: 0.0010
# Epoch 8/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.2837 - accuracy: 0.9007 - val_loss: 0.4612 - val_accuracy: 0.7931 - lr: 0.0010
# Epoch 9/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1912 - accuracy: 0.9217 - val_loss: 0.2583 - val_accuracy: 0.8922 - lr: 0.0010
# Epoch 10/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.2127 - accuracy: 0.9217 - val_loss: 0.1867 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 11/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.2130 - accuracy: 0.9276 - val_loss: 0.1414 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 12/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1825 - accuracy: 0.9346 - val_loss: 0.1236 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 13/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1650 - accuracy: 0.9556 - val_loss: 0.0983 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 14/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1725 - accuracy: 0.9404 - val_loss: 0.1311 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 15/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1384 - accuracy: 0.9486 - val_loss: 0.1180 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 16/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1367 - accuracy: 0.9509 - val_loss: 0.1140 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 17/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1175 - accuracy: 0.9579 - val_loss: 0.0678 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 18/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1144 - accuracy: 0.9626 - val_loss: 0.0841 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 19/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1103 - accuracy: 0.9568 - val_loss: 0.0782 - val_accuracy: 0.9784 - lr: 0.0010
# Epoch 20/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.1228 - accuracy: 0.9603 - val_loss: 0.0964 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 21/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1195 - accuracy: 0.9533 - val_loss: 0.0926 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 22/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.1594 - accuracy: 0.9568 - val_loss: 0.0978 - val_accuracy: 0.9784 - lr: 0.0010
# Epoch 23/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1179 - accuracy: 0.9603 - val_loss: 0.0561 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 24/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1177 - accuracy: 0.9661 - val_loss: 0.0710 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 25/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0855 - accuracy: 0.9743 - val_loss: 0.0435 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 26/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0756 - accuracy: 0.9743 - val_loss: 0.0610 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 27/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0915 - accuracy: 0.9708 - val_loss: 0.0714 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 28/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0653 - accuracy: 0.9860 - val_loss: 0.0556 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 29/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0577 - accuracy: 0.9801 - val_loss: 0.1222 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 30/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0919 - accuracy: 0.9673 - val_loss: 0.0358 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 31/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0678 - accuracy: 0.9825 - val_loss: 0.0273 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 32/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0847 - accuracy: 0.9731 - val_loss: 0.3281 - val_accuracy: 0.8664 - lr: 0.0010
# Epoch 33/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1257 - accuracy: 0.9509 - val_loss: 0.0636 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 34/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0746 - accuracy: 0.9755 - val_loss: 0.0295 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 35/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.1027 - accuracy: 0.9685 - val_loss: 0.0428 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 36/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0837 - accuracy: 0.9638 - val_loss: 0.0539 - val_accuracy: 0.9784 - lr: 0.0010
# Epoch 37/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0532 - accuracy: 0.9825 - val_loss: 0.0389 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 38/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0628 - accuracy: 0.9813 - val_loss: 0.0401 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 39/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0458 - accuracy: 0.9895 - val_loss: 0.0313 - val_accuracy: 0.9957 - lr: 0.0010
# Epoch 40/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0339 - accuracy: 0.9836 - val_loss: 0.0245 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 41/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0445 - accuracy: 0.9860 - val_loss: 0.0267 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 42/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0396 - accuracy: 0.9848 - val_loss: 0.0407 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 43/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0409 - accuracy: 0.9877 - val_loss: 0.0574 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 44/50
# 14/14 [==============================] - 51s 4s/step - loss: 0.0418 - accuracy: 0.9907 - val_loss: 0.0372 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 45/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0366 - accuracy: 0.9860 - val_loss: 0.0247 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 46/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.0442 - accuracy: 0.9883 - val_loss: 0.0213 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 47/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0390 - accuracy: 0.9836 - val_loss: 0.0172 - val_accuracy: 0.9957 - lr: 0.0010
# Epoch 48/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0335 - accuracy: 0.9860 - val_loss: 0.0255 - val_accuracy: 0.9957 - lr: 0.0010
# Epoch 49/50
# 14/14 [==============================] - 50s 4s/step - loss: 0.0400 - accuracy: 0.9860 - val_loss: 0.0168 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 50/50
# 14/14 [==============================] - 49s 4s/step - loss: 0.0516 - accuracy: 0.9813 - val_loss: 0.1473 - val_accuracy: 0.9310 - lr: 0.0010

# %%
import matplotlib.pyplot as plt
def plot_acc_loss(results, epochs):
 acc = results.history['accuracy']
 loss = results.history['loss']
 val_acc = results.history['val_accuracy']
 val_loss = results.history['val_loss']
 plt.figure(figsize=(15, 5))
 plt.subplot(121)
 plt.plot(range(1,epochs), acc[1:], label='Train_acc',scaley=False)
 plt.plot(range(1,epochs), val_acc[1:], label='Test_acc',scaley=False)
 plt.title('Accuracy over' + str(epochs) + 'Epochs', size=15)
 plt.legend()
 plt.subplot(122)
 plt.plot(range(1,epochs), loss[1:], label='Train_loss')
 plt.plot(range(1,epochs), val_loss[1:], label='Test_loss')
 plt.title('Loss over' + str(epochs) +  'Epochs', size=15)
 plt.legend()
 plt.show()
 
plot_acc_loss(results, 50)

# %%
import numpy as np
from keras.preprocessing import image

test_image = image.load_img('drive/MyDrive/Code_Test/single_prediction/covid.jpeg', target_size = (224, 224))
test_image = image.img_to_array(test_image)/255
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(train_generator.class_indices)
# Out:
# {'Covid': 0, 'Normal': 1}

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('drive/MyDrive/Code_Test/single_prediction/covid.jpeg')
imgplot = plt.imshow(img)
plt=plt.title('CT Scan of COVID-19 Positive Patient')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['multiply', 'average', 'dot', 'logging', 'add', 'concatenate', 'subtract', 'maximum', 'save', 'minimum']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
if result[0][0] == 1:
    prediction = 'normal'
else:
    prediction = 'covid'
    
print("AI's prediction is: "+ prediction)
# Out:
# AI's prediction is: covid

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

test_image = image.load_img('drive/MyDrive/Code_Test/single_prediction/normal.jpeg', target_size = (224, 224))
test_image = image.img_to_array(test_image)/255
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(train_generator.class_indices)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# {'Covid': 0, 'Normal': 1}

# %%
img=mpimg.imread('drive/MyDrive/Code_Test/single_prediction/normal.jpeg')
imgplot = plt.imshow(img)
plt=plt.title('CT Scan of COVID-19 Negative Patient')

# %%
if result[0][0] == 1:
    prediction = 'normal'
else:
    prediction = 'covid'
    
print("AI's prediction is: "+ prediction)
# Out:
# AI's prediction is: normal
